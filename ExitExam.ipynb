# %% [markdown]
# datset#1

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_excel("dataset1.xlsx")

# %%
df.head()
# Out:
#   Month DayofMonth DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0   c-8       c-21       c-7     1934            AA    ATL  DFW       732
# 1   c-4       c-20       c-3     1548            US    PIT  MCO       834
# 2   c-9        c-2       c-5     1422            XE    RDU  CLE       416
# 3  c-11       c-25       c-6     1015            OO    DEN  MEM       872
# 4  c-10        c-7       c-6     1828            WN    MDW  OMA       423
#
#   dep_delayed_15min
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 Y

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.columns
# Out:
# Index(['Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'UniqueCarrier',
#        'Origin', 'Dest', 'Distance', 'dep_delayed_15min'],
#       dtype='object')

# %% [markdown]
# 1.	Calculate the mean, median, and standard deviation for the "DepTime" column. What insights can you draw from these measures?

# %%
df.describe()
# Out:
#              DepTime      Distance
# count  100000.000000  100000.00000
# mean     1341.523880     729.39716
# std       476.378445     574.61686
# min         1.000000      30.00000
# 25%       931.000000     317.00000
# 50%      1330.000000     575.00000
# 75%      1733.000000     957.00000
# max      2534.000000    4962.00000

# %% [markdown]
# From the above dataset i have calculated the mean and std of DepTime that is mean = 1341.523880 and std = 476.378445 and it is a quick view

# %%
m=df['DepTime'].median()
print("Median =",m)
# Out:
# Median = 1330.0

# %%
p=df['DepTime'].mean()
print("Mean=",p)
# Out:
# Mean= 1341.52388

# %%
l=df['DepTime'].std()
print("Standard Deviation=",l)
# Out:
# Standard Deviation= 476.3784446151376

# %% [markdown]
# 2.	Find the distribution of flights across different "UniqueCarrier." Which carrier has the highest number of flights?

# %%
df["UniqueCarrier"].unique()
# Out:
# array(['AA', 'US', 'XE', 'OO', 'WN', 'NW', 'DL', 'OH', 'AS', 'UA', 'MQ',
#        'CO', 'EV', 'DH', 'YV', 'F9', 'AQ', 'TZ', 'HP', 'B6', 'FL', 'HA',
#        nan], dtype=object)

# %%
df["UniqueCarrier"].nunique()
# Out:
# 22

# %% [markdown]
# 4.	How many unique "Origin" and "Dest" airports are present in the dataset?

# %%
print('unique Dest=',df["Dest"].nunique())
# Out:
# unique Dest= 289

# %%
print('unique Origin=',df["Origin"].nunique())
# Out:
# unique Origin= 289

# %%
df["Origin"].nunique()
# Out:
# 289

# %% [markdown]
# 5.	Is there any relationship between the "Distance" and whether a flight is delayed? Use correlation or scatter plots to support your analysis.

# %%
sns.scatterplot(df["Distance"])
# Out:
# <Axes: ylabel='Distance'>

# %%
import matplotlib as plt

# %%
sns.scatterplot(df["dep_delayed_15min"])
# Out:
# <Axes: ylabel='dep_delayed_15min'>

# %%
sns.barplot(data=df)
# Out:
# <Axes: >

# %%
sns.heatmap

# %% [markdown]
# #Dataset 2

# %%
#Datapreprocessing

# %%
df=pd.read_excel("Dataset2.xlsx")

# %%
df
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
# ...

# %%
df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13606.000000     13609.000000
# mean    53048.284549    855.283459       320.157483       202.271934
# std     29324.095717    214.289696        85.704732        44.973272
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.301679       175.842829
# 50%     44652.000000    794.941000       296.909450       192.431733
# 75%     61332.000000    977.213000       376.507661       217.033886
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13608.000000  13608.000000   13610.000000   13611.000000  13608.000000
# mean       1.583306      0.750929   53769.027921     253.064220      0.749727
# std        0.246650      0.091961   29775.853140      59.177120      0.049089
# ...

# %%
df.shape
# Out:
# (13611, 17)

# %%
df.isna().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    5
# MinorAxisLength    2
# AspectRation       3
# Eccentricity       3
# ConvexArea         1
# EquivDiameter      0
# Extent             3
# Solidity           1
# roundness          3
# Compactness        2
# ShapeFactor1       2
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
null_columns=['MajorAxisLength','MinorAxisLength',
       'AspectRation', 'Eccentricity', 'ConvexArea', 'Extent',
       'Solidity', 'roundness', 'Compactness', 'ShapeFactor1']

# %%
df[null_columns].isna().sum()
# Out:
# MajorAxisLength    5
# MinorAxisLength    2
# AspectRation       3
# Eccentricity       3
# ConvexArea         1
# Extent             3
# Solidity           1
# roundness          3
# Compactness        2
# ShapeFactor1       2
# dtype: int64

# %% [markdown]
# outliers

# %%
sns.boxplot(data=df,x=None,y=None,)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
#        'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
#        'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
#        'ShapeFactor3', 'ShapeFactor4', 'Class'],
#       dtype='object')

# %%
df.fillna(0)
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
df.isna().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    5
# MinorAxisLength    2
# AspectRation       3
# Eccentricity       3
# ConvexArea         1
# EquivDiameter      0
# Extent             3
# Solidity           1
# roundness          3
# Compactness        2
# ShapeFactor1       2
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
Imputer=SimpleImputer()
df=Imputer.fit_transform()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[296], line 2
#       1 Imputer=SimpleImputer()
# ----> 2 df=Imputer.fit_transform()
#
# TypeError: TransformerMixin.fit_transform() missing 1 required positional argument: 'X'
